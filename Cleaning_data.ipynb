# %%
import pandas as pd

# %%
# Importando o dataframe
tech_data = pd.read_csv('C:/Users/lucas/Desktop/Projeto/TechnologyIndex.csv')
tech_data.head()
# Out:
#    Rank               Country   iPhone  Android    MacBook Windows Powered  \
# 0     1                Kuwait  $641.50  $539.18    $795.38         $528.34
# 1     2          Saudi Arabia  $513.86  $699.61  $1,054.98         $686.88
# 2     3              Malaysia  $532.06  $631.66  $1,010.31       $1,022.67
# 3     4                Canada  $555.25  $625.04  $1,118.10       $1,081.40
# 4     5  United Arab Emirates  $498.25  $592.31  $1,073.30       $1,026.68
#
#        PS4 Xbox one iPad mini Samsung tablet 40 inch smart TV Apple Watch  \
# 0  $315.83  $418.50   $242.90        $250.98          $383.60     $242.90
# 1  $317.86  $254.24   $380.47        $152.44          $406.93     $381.48
# 2  $299.83  $355.47   $232.87        $354.99          $324.87     $248.43
# 3  $274.25  $233.14   $237.34        $392.89          $364.30     $259.21
# 4  $324.72  $285.72   $259.71        $311.71          $467.68     $285.71
#
#   Brand headphone hard drive 2TB Portable charger  Printer
# ...

# %%
# Limpeza de dados do dataframe
tech_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank              72 non-null     int64
#  1   Country           72 non-null     object
#  2   iPhone            72 non-null     object
#  3   Android           72 non-null     object
#  4   MacBook           72 non-null     object
#  5   Windows Powered   72 non-null     object
#  6   PS4               72 non-null     object
#  7   Xbox one          72 non-null     object
#  8   iPad mini         72 non-null     object
#  9   Samsung tablet    72 non-null     object
#  10  40 inch smart TV  72 non-null     object
#  11  Apple Watch       72 non-null     object
#  12  Brand headphone   72 non-null     object
#  13  hard drive 2TB    72 non-null     object
#  14  Portable charger  72 non-null     object
#  15  Printer           72 non-null     object
# ...

# %%
tech_data.isna().any() # Não possue valores nulos
# Out:
# Rank                False
# Country             False
# iPhone              False
# Android             False
# MacBook             False
# Windows Powered     False
# PS4                 False
# Xbox one            False
# iPad mini           False
# Samsung tablet      False
# 40 inch smart TV    False
# Apple Watch         False
# Brand headphone     False
# hard drive 2TB      False
# Portable charger    False
# Printer             False
# dtype: bool

# %%
# Removendo '$' de todas as linhas e colunas
tech_data.columns
colunas = tech_data[['iPhone', 'Android', 'MacBook', 'Windows Powered',
       'PS4', 'Xbox one', 'iPad mini', 'Samsung tablet', '40 inch smart TV',
       'Apple Watch', 'Brand headphone', 'hard drive 2TB', 'Portable charger',
       'Printer']]


for col in colunas:
    tech_data[col] = tech_data[col].str.replace('$', '')

tech_data
# Out:
#     Rank               Country     iPhone    Android     MacBook  \
# 0      1                Kuwait     641.50     539.18      795.38
# 1      2          Saudi Arabia     513.86     699.61    1,054.98
# 2      3              Malaysia     532.06     631.66    1,010.31
# 3      4                Canada     555.25     625.04    1,118.10
# 4      5  United Arab Emirates     498.25     592.31    1,073.30
# ..   ...                   ...        ...        ...         ...
# 67    68             Guatemala     889.56     591.31    1,525.26
# 68    69                Brazil     843.30     948.74    3,390.96
# 69    70                Brunei     764.02     856.47    2,326.47
# 70    71                Angola     401.94   2,641.01    1,001.06
# 71    72             Venezuela  97,813.82  78,054.19  176,005.34
#
#    Windows Powered        PS4   Xbox one  iPad mini Samsung tablet  \
# 0           528.34     315.83     418.50     242.90         250.98
# ...

# %%
# Removendo ',' de todas as linhas e colunas

for col in colunas:
    tech_data[col] = tech_data[col].str.replace(',', '')

tech_data
# Out:
#     Rank               Country    iPhone   Android    MacBook Windows Powered  \
# 0      1                Kuwait    641.50    539.18     795.38          528.34
# 1      2          Saudi Arabia    513.86    699.61    1054.98          686.88
# 2      3              Malaysia    532.06    631.66    1010.31         1022.67
# 3      4                Canada    555.25    625.04    1118.10         1081.40
# 4      5  United Arab Emirates    498.25    592.31    1073.30         1026.68
# ..   ...                   ...       ...       ...        ...             ...
# 67    68             Guatemala    889.56    591.31    1525.26         2055.53
# 68    69                Brazil    843.30    948.74    3390.96          564.91
# 69    70                Brunei    764.02    856.47    2326.47         1545.52
# 70    71                Angola    401.94   2641.01    1001.06         1574.17
# 71    72             Venezuela  97813.82  78054.19  176005.34        35941.09
#
# ...

# %%
# Corrigindo o Dtype das colunas

for col in colunas:
    tech_data[col] = tech_data[col].astype(dtype='float')

tech_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank              72 non-null     int64
#  1   Country           72 non-null     object
#  2   iPhone            72 non-null     float64
#  3   Android           72 non-null     float64
#  4   MacBook           72 non-null     float64
#  5   Windows Powered   72 non-null     float64
#  6   PS4               72 non-null     float64
#  7   Xbox one          72 non-null     float64
#  8   iPad mini         72 non-null     float64
#  9   Samsung tablet    72 non-null     float64
#  10  40 inch smart TV  72 non-null     float64
#  11  Apple Watch       72 non-null     float64
#  12  Brand headphone   72 non-null     float64
#  13  hard drive 2TB    72 non-null     float64
#  14  Portable charger  72 non-null     float64
#  15  Printer           72 non-null     float64
# ...

# %%
# Salvando o banco de dados limpo
tech_data.to_csv('cleaned_data.csv', index=False)
